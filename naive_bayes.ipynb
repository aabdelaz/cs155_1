# %%
import numpy as np
from sklearn.naive_bayes import MultinomialNB

# %%
train_data = load_data("./data/training_data.txt")
X, y = process_training_data(train_data, 'tfidf', add_bias=True)
test_data = load_data("./data/testing_data.txt")
X_test, y_test = process_training_data(test_data, 'tfidf', add_bias=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-014a2be12fa1> in <module>()
# ----> 1 train_data = load_data("./data/training_data.txt")
#       2 X, Y = process_training_data(train_data, 'l1', add_bias=True)
#
# NameError: name 'load_data' is not defined

# %%
clf = MultinomialNB()
clf.fit(X, y)

predicted = clf.predict(X_test)
#then evaluate the error
